# %% [markdown]
# <a href="https://colab.research.google.com/github/Naya019/my-api/blob/main/Estrair%20corrdenadas%20de%20cidades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nova seção

# %%
# !pip install geopandas

# %%
# !pip install pandas

# %%
import geopandas as gpds
import pandas as pd

# %%
gpds.tools.geocode('JOINVILLE / SC', provider = 'nominatim', user_agent = 'my_application')
# Out:
#                       geometry  \
# 0  POINT (-48.84867 -26.30449)
#
#                                              address
# 0  Joinville, Região Geográfica Imediata de Joinv...

# %%
df = pd.read_excel('/content/data2.xlsx')
df.head()
# Out:
#                   Column1
# 0  ABADIA DOS DOURADOS/MG
# 1               ABAETE/MG
# 2           ABAETETUBA/PA
# 3               ABATIA/PR
# 4           ABRE CAMPO/MG

# %%
from datetime import time
df['Coordenadas'] = gpds.tools.geocode(df['Column1'], provider = 'nominatim', user_agent = 'my_application')['geometry']
time.sleep(1)

# %% [markdown]
# df.to_csv('Base coordenada.csv')
